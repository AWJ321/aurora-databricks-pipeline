# %%
import os

# Path to cluster home
config_path = os.path.expanduser("~/.ecmwfapirc")

# Replace YOUR_KEY and YOUR_EMAIL with your actual credentials
ecmwf_content = """{
    "url"   : "https://api.ecmwf.int/v1",
    "key"   : "4d78e88f73c8101e803497ea661005d1",
    "email" : "mss_data_service@nea.gov.sg"
}"""

# Write the file
with open(config_path, "w") as f:
    f.write(ecmwf_content)

print("Created .ecmwfapirc at:", config_path)
print("Exists:", os.path.exists(config_path))
